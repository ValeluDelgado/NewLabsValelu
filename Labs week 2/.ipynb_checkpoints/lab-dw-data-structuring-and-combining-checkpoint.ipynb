# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# Objective:
# - Combine and integrate data from multiple sources using merging, concatenating, or joining techniques to generate more comprehensive and meaningful datasets for analysis.
# - Modify the structure of data by pivoting, stacking/unstacking, or melting dataframes, enabling them to efficiently explore and analyze complex datasets.

# %% [markdown]
# # Challenge 1: Combining Data

# %% [markdown]
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the following links:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv

# %% [markdown]
# Perform data cleaning and formatting using the main cleaning and formatting function created in the previous lab to clean and format the data.

# %% [markdown]
# Combine the data from the three dataframes into a single dataframe, named "customer_data", using appropriate merging, concatenating, and joining techniques.
#
# Verify that the customer_data dataframe contains all the rows and columns from the three original dataframes.

# %% [markdown]
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
pd.options.display.max_rows = 100
import warnings
warnings.filterwarnings("ignore")
## Install xlrd package to load Excel files
#!conda install openpyxl
#!conda install xlrd

# %% [markdown]
# I will read each one to know how to concatenate, in which axis:

# %%
file_1 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')

# %%
file_1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file_2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')

# %%
file_2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
file_3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')

# %%
file_3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %% [markdown]
# First I standarize the names of the columns of the three sets and then I will merge them:

# %%
def lower_case_column_names(file_1):
    file_1.columns=[i.lower() for i in file_1.columns]
    return file_1

# %%
file_1 = lower_case_column_names(file_1)

# %%
file_1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def lower_case_column_names(file_2):
    file_2.columns=[i.lower() for i in file_2.columns]
    return file_2

# %%
file_2 = lower_case_column_names(file_2)
file_2
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
def lower_case_column_names(file_3):
    file_3.columns=[i.lower() for i in file_3.columns]
    return file_3

# %%
file_3 = lower_case_column_names(file_3)
file_3
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %% [markdown]
# Then I will rename each of them:

# %%
def rename_columns(file_1):
    file_1.rename(columns={'customer':'customer_id','st':'state'}, inplace=True )
    return file_1

# %%
file_1 = rename_columns(file_1)
file_1
# Out:
#      customer_id       state gender             education  \
# 0        RB50392  Washington    NaN                Master
# 1        QZ44356     Arizona      F              Bachelor
# 2        AI49188      Nevada      F              Bachelor
# 3        WW63253  California      M              Bachelor
# 4        GA49547  Washington      M  High School or Below
# ...          ...         ...    ...                   ...
# 4003         NaN         NaN    NaN                   NaN
# 4004         NaN         NaN    NaN                   NaN
# 4005         NaN         NaN    NaN                   NaN
# 4006         NaN         NaN    NaN                   NaN
# 4007         NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def rename_columns(file_2):
    file_2.rename(columns={'customer':'customer_id','st':'state'}, inplace=True )
    return file_2

# %%
file_2 = rename_columns(file_2)
file_2
# Out:
#     customer_id       state gender education customer lifetime value  income  \
# 0       GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1       CW49887  California      F    Master              462680.11%   79487
# 2       MY31220  California      F   College              899704.02%   54230
# 3       UH35128      Oregon      F   College             2580706.30%   71210
# 4       WH52799     Arizona      F   College              380812.21%   94903
# ..          ...         ...    ...       ...                     ...     ...
# 991     HV85198     Arizona      M    Master              847141.75%   63513
# 992     BS91566     Arizona      F   College              543121.91%   58161
# 993     IL40123      Nevada      F   College              568964.41%   83640
# 994     MY32149  California      F    Master              368672.38%       0
# 995     SA91515  California      M  Bachelor              399258.39%       0
#
# ...

# %%
def rename_columns(file_3):
    file_3.rename(columns={'customer':'customer_id','st':'state'}, inplace=True )
    return file_3

# %%
file_3 = rename_columns(file_3)
file_3
# Out:
#      customer_id       state  customer lifetime value             education  \
# 0        SA25987  Washington              3479.137523  High School or Below
# 1        TB86706     Arizona              2502.637401                Master
# 2        ZL73902      Nevada              3265.156348              Bachelor
# 3        KX23516  California              4455.843406  High School or Below
# 4        FN77294  California              7704.958480  High School or Below
# ...          ...         ...                      ...                   ...
# 7065     LA72316  California             23405.987980              Bachelor
# 7066     PK87824  California              3096.511217               College
# 7067     TD14365  California              8163.890428              Bachelor
# 7068     UP19263  California              7524.442436               College
# 7069     Y167826  California              2611.836866               College
#
# ...

# %% [markdown]
# Now that the names of the columns are the same I concatenate:

# %%
file_123 = pd.concat([file_1, file_2, file_3])
file_123
# Out:
#      customer_id       state gender             education  \
# 0        RB50392  Washington    NaN                Master
# 1        QZ44356     Arizona      F              Bachelor
# 2        AI49188      Nevada      F              Bachelor
# 3        WW63253  California      M              Bachelor
# 4        GA49547  Washington      M  High School or Below
# ...          ...         ...    ...                   ...
# 7065     LA72316  California      M              Bachelor
# 7066     PK87824  California      F               College
# 7067     TD14365  California      M              Bachelor
# 7068     UP19263  California      M               College
# 7069     Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# Now, I clean!

# %%
#I clean gender: 

def clean_gender(x):
    if x in ['F','Femal','female']:
        return 'Female'
    elif x in ['M','Male']:
        return 'Male'
    else:
        return np.nan

# %%
file_123['gender'] = list(map(clean_gender, file_123['gender']))

# %%
file_123
# Out:
#      customer_id       state  gender             education  \
# 0        RB50392  Washington     NaN                Master
# 1        QZ44356     Arizona  Female              Bachelor
# 2        AI49188      Nevada  Female              Bachelor
# 3        WW63253  California    Male              Bachelor
# 4        GA49547  Washington    Male  High School or Below
# ...          ...         ...     ...                   ...
# 7065     LA72316  California    Male              Bachelor
# 7066     PK87824  California  Female               College
# 7067     TD14365  California    Male              Bachelor
# 7068     UP19263  California    Male               College
# 7069     Y167826  California    Male               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#Clean state (is not working)

# %%
file_123.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_id                9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    2060 non-null   float64
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(4), object(7)
# memory usage: 1.1+ MB

# %% [markdown]
# changing number of open complaints to float:

# %%
file_123["number of open complaints"] = file_123["number of open complaints"].apply(lambda x: x.split('/')[1] if type(x)==str else x)

# %%
file_123["number of open complaints"] = file_123["number of open complaints"].astype(dtype ="float64")

# %%
file_123.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer_id                9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    2060 non-null   float64
#  5   income                     9137 non-null   float64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  9137 non-null   float64
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 1.1+ MB

# %%
Calculate the percentage of nulls:

# %%
def calculate_percent_nulls(df):
    nulls_df = pd.DataFrame(round(df.isna().sum() / len(df), 4) * 100)
    nulls_df = nulls_df.reset_index()
    nulls_df.columns = ['header_name', 'percent_nulls']
    return nulls_df

# %%
calculate_percent_nulls(file_123)
# Out:
#                   header_name  percent_nulls
# 0                 customer_id          24.32
# 1                       state          24.32
# 2                      gender          25.34
# 3                   education          24.32
# 4     customer lifetime value          82.94
# 5                      income          24.32
# 6        monthly premium auto          24.32
# 7   number of open complaints          24.32
# 8                 policy type          24.32
# 9               vehicle class          24.32
# 10         total claim amount          24.32

# %% [markdown]
# Based on this I will drop customer life time value:

# %%
file_123 = file_123.dropna(subset = "customer lifetime value")
file_123
# Out:
#     customer_id       state  gender             education  \
# 1       QZ44356     Arizona  Female              Bachelor
# 2       AI49188      Nevada  Female              Bachelor
# 3       WW63253  California    Male              Bachelor
# 4       GA49547  Washington    Male  High School or Below
# 5       OC83172      Oregon  Female              Bachelor
# ..          ...         ...     ...                   ...
# 991     HV85198     Arizona    Male                Master
# 992     BS91566     Arizona  Female               College
# 993     IL40123      Nevada  Female               College
# 994     MY32149  California  Female                Master
# 995     SA91515  California    Male              Bachelor
#
#      customer lifetime value   income  monthly premium auto  \
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# 3                  764586.18      0.0                 106.0
# ...

# %% [markdown]
# Then, I remove duplicates from costumer:

# %%
def remove_dups(x):
    x.drop_duplicates(subset = "customer_id",ignore_index = True, inplace=True)
    return x

# %%
remove_dups(file_123)
# Out:
#      customer_id       state  gender             education  \
# 0        QZ44356     Arizona  Female              Bachelor
# 1        AI49188      Nevada  Female              Bachelor
# 2        WW63253  California    Male              Bachelor
# 3        GA49547  Washington    Male  High School or Below
# 4        OC83172      Oregon  Female              Bachelor
# ...          ...         ...     ...                   ...
# 2052     HV85198     Arizona    Male                Master
# 2053     BS91566     Arizona  Female               College
# 2054     IL40123      Nevada  Female               College
# 2055     MY32149  California  Female                Master
# 2056     SA91515  California    Male              Bachelor
#
#       customer lifetime value   income  monthly premium auto  \
# 0                   697953.59      0.0                  94.0
# 1                  1288743.17  48767.0                 108.0
# 2                   764586.18      0.0                 106.0
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %% [markdown]
# ## Exercise 1: Clean and Format the Data

# %% [markdown]
# While the dataset has been partially cleaned and formatted, we still need to perform several data cleaning tasks. Specifically, we need to standardize the column names, clean null values, convert the effective_to_date column to datetime, and extract the months from the dataset and store them in a separate column.
#
# To accomplish these tasks, we will use the functions created in the previous step to standardize the column names and deal with null values, and then we will apply additional functions to convert the effective_to_date column to datetime and extract the months.
#
# Save the clean dataset into a csv file.

# %%
# Your code goes here

# %%
df4 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv')

# %%
df4
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
df4 = df4.drop(['Unnamed: 0'], axis=1)

# %%
df4
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10910 entries, 0 to 10909
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Customer                       10910 non-null  object
#  1   State                          10279 non-null  object
#  2   Customer Lifetime Value        10910 non-null  float64
#  3   Response                       10279 non-null  object
#  4   Coverage                       10910 non-null  object
#  5   Education                      10910 non-null  object
#  6   Effective To Date              10910 non-null  object
#  7   EmploymentStatus               10910 non-null  object
#  8   Gender                         10910 non-null  object
#  9   Income                         10910 non-null  int64
#  10  Location Code                  10910 non-null  object
#  11  Marital Status                 10910 non-null  object
# ...

# %% [markdown]
# Standarize name columns:

# %%
def lower_case_column_names(x):
    x.columns=[i.lower() for i in x.columns]
    return x

# %%
lower_case_column_names(df4)
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %%
df4.rename(columns={'employmentstatus':'employment status'}, inplace=True )

# %%
df4
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       education effective to date employment status gender  income  ...  \
# ...

# %% [markdown]
# Now I will work remove the null values:

# %%
def calculate_percent_nulls(df):
    nulls_df = pd.DataFrame(round(df.isna().sum() / len(df), 4) * 100)
    nulls_df = nulls_df.reset_index()
    nulls_df.columns = ['header_name', 'percent_nulls']
    return nulls_df

# %%
calculate_percent_nulls(df4)
# Out:
#                       header_name  percent_nulls
# 0                        customer           0.00
# 1                           state           5.78
# 2         customer lifetime value           0.00
# 3                        response           5.78
# 4                        coverage           0.00
# 5                       education           0.00
# 6               effective to date           0.00
# 7               employment status           0.00
# 8                          gender           0.00
# 9                          income           0.00
# 10                  location code           0.00
# 11                 marital status           0.00
# 12           monthly premium auto           0.00
# 13        months since last claim           5.80
# 14  months since policy inception           0.00
# 15      number of open complaints           5.80
# 16             number of policies           0.00
# 17                    policy type           0.00
# ...

# %% [markdown]
# Based on this I will remove the null of vehicle type:

# %%
df4 = df4.dropna(subset = "vehicle type")

# %%
df4
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 5      HO81102         NaN              4745.181764      NaN     Basic
# 10     HG93801     Arizona              5154.764074       No  Extended
# 13     KR82385  California              5454.587929       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective to date employment status gender  \
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5428 entries, 2 to 10908
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       5428 non-null   object
#  1   state                          5115 non-null   object
#  2   customer lifetime value        5428 non-null   float64
#  3   response                       5115 non-null   object
#  4   coverage                       5428 non-null   object
#  5   education                      5428 non-null   object
#  6   effective to date              5428 non-null   object
#  7   employment status              5428 non-null   object
#  8   gender                         5428 non-null   object
#  9   income                         5428 non-null   int64
#  10  location code                  5428 non-null   object
#  11  marital status                 5428 non-null   object
# ...

# %% [markdown]
# Change the type to datetime:

# %%
# convert the 'Date' column to datetime format
df4['effective to date']= pd.to_datetime(df4['effective to date'])
# Out:
# /var/folders/2k/4xrmmln9749_gpnkt8_q2md80000gn/T/ipykernel_64187/2549429700.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4['effective to date']= pd.to_datetime(df4['effective to date'])

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5428 entries, 2 to 10908
# Data columns (total 25 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer                       5428 non-null   object
#  1   state                          5115 non-null   object
#  2   customer lifetime value        5428 non-null   float64
#  3   response                       5115 non-null   object
#  4   coverage                       5428 non-null   object
#  5   education                      5428 non-null   object
#  6   effective to date              5428 non-null   datetime64[ns]
#  7   employment status              5428 non-null   object
#  8   gender                         5428 non-null   object
#  9   income                         5428 non-null   int64
#  10  location code                  5428 non-null   object
#  11  marital status                 5428 non-null   object
# ...

# %% [markdown]
# Now I create a new column with the month:

# %%
import datetime

# %%
df4['month'] = pd.DatetimeIndex(df4['effective to date']).month

# %%
df4
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 5      HO81102         NaN              4745.181764      NaN     Basic
# 10     HG93801     Arizona              5154.764074       No  Extended
# 13     KR82385  California              5454.587929       No     Basic
# ...        ...         ...                      ...      ...       ...
# 10903  SU71163     Arizona              2771.663013       No     Basic
# 10904  QI63521      Nevada             19228.463620       No     Basic
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10908  WA60547  California             11971.977650       No   Premium
#
#                   education effective to date employment status gender  \
# ...

# %% [markdown]
# ## Exercise 2: Structuring Data

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total_claim_amount to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %% [markdown]
# 3. You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here

# %% [markdown]
# You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail). Round the total_claim_amount to 2 decimal points. Analyze the resulting table to draw insights.

# %%
pivot_table = pd.pivot_table(df4, values ='total claim amount', index='sales channel', aggfunc='sum')

# %%
pivot_table['total claim amount'] = pivot_table['total claim amount'].round(2)

# %%
print(pivot_table)
# Out:
#                total claim amount
# sales channel
# Agent                   889339.39
# Branch                  649954.10
# Call Center             477145.04
# Web                     356581.25

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_table = pd.pivot_table(df4, values='customer lifetime value', index=['gender', 'education'], aggfunc='mean')
print(pivot_table)
# Out:
#                              customer lifetime value
# gender education
# F      Bachelor                          8008.332617
#        College                           7733.514504
#        Doctor                            8110.802851
#        High School or Below              8608.341165
#        Master                            8284.448533
# M      Bachelor                          7944.787242
#        College                           8135.241462
#        Doctor                            7419.559369
#        High School or Below              8038.931080
#        Master                            8084.569889

# %% [markdown]
# 3. You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %%
summary_table = df4.groupby(['policy type', 'month']).size().reset_index(name='number of open complaints')

# %%
print(summary_table)
# Out:
#       policy type  month  number of open complaints
# 0  Corporate Auto      1                        586
# 1  Corporate Auto      2                        549
# 2   Personal Auto      1                       2170
# 3   Personal Auto      2                       1882
# 4    Special Auto      1                        122
# 5    Special Auto      2                        119
